# %% [markdown]
# # Course 1 - Prompting for Effective LLM Reasoning and Planning
#
# Table of Contents
#
# 0. [Pre-Requisites](#0)
# 1. [Introduction to Prompting for Effective LLM Reasoning and Planning](#1)
# 2. [The Role of Prompting in Agentic AI with Python and OpenAI](#2)
# 3. [Role-Based Prompting](#3)
# 4. [Implementing Role-Based Prompting with Python](#4)
# 5. [Chain-of-Thought and ReACT Prompting](#5)
# 6. [Applying CoT and ReACT Prompting with Python](#6)
# 7. [Prompt Instruction Refinement](#7)
# 8. [Applying Prompt Instruction Refinement](#8)
# 9. [Chaining Prompts for Agentic Reasoning](#9)
# 10. [Chaining Prompts with Python](#10)
# 11. [LLM Feedback Loops](#11)
# 12. [Implementing LLM Feedback Loops with Python](#12)

# %% [markdown]
# ## 0. Pre-Requisites
#
# To be sure you have a smooth and successful learning experience, please review the following prerequisites.
#
# **Core Knowledge and Skills:**
#
# 1. **Basic Python Programming:** You should be comfortable with Python syntax, common data types (strings, lists, dictionaries), writing functions, and the general flow of a Python script.
# 2. **Jupyter Notebook Proficiency:** Familiarity with navigating the Jupyter Notebook interface, executing code cells, and understanding their output is essential.
# 3. **Foundational Understanding of LLMs:** You should know what a Large Language Model (LLM) is at a conceptual level, including its general capabilities (e.g., text generation, understanding) and the basic idea of using "prompts" to interact with it.
#
# **Recommended Background:**
#
# * If you are new to Generative AI, LLMs, or the fundamentals of prompting, completing Udacity's [Generative AI Nanodegree](https://www.udacity.com/course/generative-ai--nd608) will provide you with the necessary foundational knowledge to get the most out of this material.
#
# **To Be Successful in This Course, You'll Need To:**
#
# * Be ready to apply your Python skills to write and modify code that interacts with an LLM API within a Jupyter Notebook environment.
# * Have a curious and experimental mindset, willing to try different prompt structures and observe their effects.
# * While deep expertise isn't required, a basic understanding of how APIs work (i.e., sending a request and recieving a response) will be beneficial
#
# **Learning Environment & Resources**
#
# This course is designed to be hands-on. Here’s what you need to know about the computing environment and resources you'll be using.
#
# **Classroom Workspaces:**
#
# * Throughout this course, you will have access to Udacity's integrated classroom workspaces.
# * These workspaces come pre-configured with Jupyter Notebook and Visual Studio Code environments. This means you can write and execute Python code, interact with LLMs, and complete all hands-on labs directly in your web browser. No local software installation is required to use the classroom workspace.
#
# **Cloud Lab Resources (OpenAI API Access):**
#
# * For exercises that require interaction with Large Language Models, you will be granted access to an OpenAI API Key via our platform.
# * This key is linked to a specific budget allocated for your use throughout the course. This allows you to experiment with powerful models without incurring personal costs, within the defined limits.
# * Detailed instructions on how to find your API key, understand the budget, and properly configure it within the Jupyter Notebooks will be provided on the next page. Please follow those instructions carefully.
#
# **Optional: Working Locally or With Personal/Company Accounts**
#
# While the Udacity classroom workspace provides everything you need, if you prefer to work on your local machine or use your own personal/company OpenAI (or other provider's) accounts, here’s what you'll generally need to set up:
#
# 1. **Python Installation:**
# * Python installed on your system (Python 3.10 or newer is recommended). You can download it from the official website: [python.org](https://www.python.org/)
# 2. **Jupyter Notebook/Lab:**
# * You'll need to install Jupyter Notebook, JupyterLab, or use Visual Studio Code with the Jupyter Notebook extension. This can typically be done using pip after installing Python:
# 3. **OpenAI Python Library:**
# * The course materials use the official OpenAI Python library.
# ```shell
# pip install openai
# ```
# (Use version 1.0.0 or later as older versions have different syntax)
# 4. **API Key Configuration (Local/Personal Account):**
# * You will need to obtain your own API key from your chosen LLM provider (e.g., from the [OpenAI Platform website](https://platform.openai.com/api-keys) if using your personal OpenAI account).
# * Be aware that you will be responsible for any costs incurred when using your personal or company API keys.
# * To use your key in the lab code (which is often set up to read from an environment variable), you would typically:
# > * Set an environment variable named OPENAI_API_KEY to your actual key value. The method for setting environment variables differs by operating system.
# > * Alternatively, you might modify the Python code directly to include your API key, though using environment variables is generally recommended for security:
# ```python
# #Example for directly inserting your key - use with caution
# from openai import OpenAI
# client = OpenAI(api_key="sk-YOUR_ACTUAL_API+KEY_HERE")
# ```
# 5. **Other Python Libraries:**
# * If specific labs require additional Python libraries, they will be mentioned in the notebook. You can usually install them using pip:
# ```shell
# pip install <library_name>
# ```
# We recommend using the provided classroom workspace for the most straightforward experience, as it's tailored for the course content and includes API access.

# %% [markdown]
# ## 1. Introduction to Prompting for Effective LLM Reasoning and Planning
#
# Introduces the core concepts of Agentic AI, the course structure, prerequisites, and learning environment.
#
# **Unlocking Advanced AI: Prompting for LLM Reasoning and Planning**
#
# This learning path is designed to equip you with powerful prompting techniques essential for building sophisticated AI agents. Mastering these skills allows you to guide LLMs through complex, multi-step tasks, improving the accuracy, relevance, and utility of their outputs for real-world applications.
#
# This learning journey is focused on how advanced prompting techniques enable AI applications to become AI agents. By the end of the journey, you'll understand the mechanics and possess the skills to apply prompting techniques to agentic AI systems.
#
# **The Need for Agentic AI: Debugging Complex Code**
#
# Imagine you're tasked with building an automated system to help developers debug complex code. Simply feeding the buggy code and the error message into a standard LLM often results in generic suggestions that miss the specific context of the larger project. The LLM might suggest superficial fixes or even introduce new bugs.
#
# How can you create an AI assistant that acts more like an experienced senior developer – one that can break down the problem, hypothesize potential causes, decide which parts of the code to inspect, integrate information from different files, update tests, and even learn from its failures? This requires moving beyond single-shot prompts to build a system capable of multi-step reasoning, planning, and execution – precisely the prompting techniques we'll master.

# %% [markdown]
# Knowledge Check: Are you ready?
#
# 1. In the context of interacting with a Large Language Model, what is a "prompt":
# > A. A software library used to connect to the LLM<br>
# > B. The input text or instructions provided to the LLM to guide its response<br>
# > C. The underlying algorithm the LLM uses for generation<br>
# > D. The error messages returned by the LLM if it fals<br>
#
# <details><summary>Answer</summary>
# B. The input text or instructions provided to the LLM to guide its response
# </details>
#
# 2. Which of the following best describes a Large Language Model?
# > A. A type of advanced spell-checker integrated into word processors<br>
# > B. A hardware accelerator used for speeding up natural language processing tasks<br>
# > C. A relational database specifically designed for storing and retrieving textual information<br>
# > D. A machine learning model trained on vast amounts of text data to understand, summarize, generate, and predict content<br>
#
# <details><summary>Answer</summary>
# D. A machine learning model trained on vast amounts of text data to understand, summarize, generate, and predict content
# </details>
#
# 3. What is the primary purpose of a Python dictionary?
# > A. Store an ordered sequence of items<br>
# > B. Store key-value pairs<br>
# > C. Perform mathematical calculations<br>
# > D. Define reusable blocks of code<br>
#
# <details><summary>Answer</summary>
# B. Store key-value pairs
# </details>
#
# 4. In a Jupyter Notebook, how do you typically execute a code cell and see its output?
# > A. Type 'execute' at the end of the cell<br>
# > B. Right-clicking the cell and selecting 'compile'<br>
# > C. Executes automatically as you type<br>
# > D. Selecting the cell and pressing Shift + Enter (or using a 'Run' button in the interface)
#
# <details><summary>Answer</summary>
# > D. Selecting the cell and pressing Shift + Enter (or using a 'Run' button in the interface)
# </details>

# %% [markdown]
# **Project: Agentsville Trip Planner**
#
# **Throughout this course, you'll explore:**
# * The world of AI Agents, understanding their core components and how they reason, plan, and interact with their digital environments.
# * The art and science of advanced prompting techniques, mastering how to instruct LLMs with precision and nuance.
# * Crafting specialized personas using role-based prompting to make AI outputs more targeted and contextually relevant.
# * Unlocking problem-solving abilities using Chain-of-Thought (CoT) to guide the LLM's reasoning process and ReAct (Reason + Act) to enable LLMs to use tools and take actions.
# * The process of prompt instruction refinement, learning to systematically analyze and adjust your prompts for optimal performance.
# * Building multi-step agentic workflows by chaining prompts together, allowing AI to tackle more complex tasks.
# * **Prompt Chaining & Feedback Loops:** Building robust, multi-step workflows that allow an AI to tackle complex tasks and even improve its own work based on feedback.
#
# **End of Course Project: Agentsville Trip Planner**
#
# At the end of the course, you'll attempt to build the "Agentsville Trip Planner Assistant" project, a smart agent that can take a complex request and see it through to completion. This is your opportunity to see just how powerful prompting can be in agentic AI. You will apply all of the individual skills you learned to create a truly capable system
#
# **Get ready to move beyond basic interactions and learn how to architect and guide AI.**
#
# By the end of this journey, you will have acquired the skills to:
# * Explain AI systems that utilize LLMs for sophisticated reasoning and planning capabilities.
# * Master a range of advanced prompting strategies to elicit precise behavior and information from LLMs.
# * Systematically optimize and refine your prompts, transforming general AI responses into highly specific and useful outputs.
# * Construct multi-step AI workflows that can handle complex, real-world challenges.
# * Implement mechanisms for validation and iterative improvement, leading to more reliable AI agents.
# * Ultimately, transform generic Large Language Models into specialized, powerful tools tailored to solve intricate problems across various domains.
#
# This course will both challenge you and equip you with the cutting-edge skills needed to innovate in the rapidly evolving field of artificial intelligence. We're excited to see what you'll learn and, eventually, what you'll build. Good luck!

# %% [markdown]
# ## 2. The Role of Prompting in Agentic AI with Python and OpenAI
#
# **What is an AI Agent?**
# An *AI Agent* is an intelligent system capable of perceiving its environment, making decisions, and taking actions to achieve specific goals. Key characteristics include autonomy, adaptability, and interationc with its surroundings.
#
# While traditional *AI Systems* might simply compute or follow static rules, agents are designed for *autonomy*, *adaptability*, and *interaction* with their surroundings. They the power of generative AI, particularly Large Language Models (LLMs) a step further.
#
# Agents can work alongside you or independently on your behalf. They can handle a range of tasks, from simple responses to more complicated multistep assignments. AI Agents move beyond static rules or simple generation to **reasoning, planning, and acting** towards a goal using tools. They give LLMs the capability to reason, plan, and act in an environment - like you computer, the internet, or the phyiscal world - to achieve a goal
#
# > **An agent decides on actions, potentially using external tools, and observes the results to inform its next steps**
#
# ### Components of an AI Agent
#
# The foundation of a modern AI agent typically involves several key components:
# 1. **Large Language Model (LLM)**: this serves as the "brain" of the agent, providing the ability to understand, reason, and act (ReAct). LLMs process and generate language, enabling the agent's cognitive functions.
# 2. **Tools**: These are external functions, APIs, or resources that the agent can access and utilize to interact with its environment and enhance its capabilities. Tools allow agens to perform specific tasks beyond text generation, such as searchign the web, querying databases, making calucluations, or controlling external systems
# 3. **Instructions**: Explicit guidelines, often provided through a system prompt, define how the agent should behave and guide its actions
# 4. **Memory**: Agents can possess various forms of memory, including short-term memory (context from the current conversation) and long-term memory (from past historical interactions), enabling them to learn from past experiences and maintain context
# 5. **Runtime/Orchestration Layer**: This environment allos the agent or LLM to control its exectuation flow, decide when to use tools, and process observations. The orchestration layer is what actually runs the tools on the LLMs behalf, since by itself it only generates text
#
# Knowledge Check:
# > You are designing an AI assistant to help users with financial questions. A user asks: "Based on my current checking account balance, can I afford to buy the new `X-1` laptop that was just released?"
# > A standard LLM cannot answer this question directly because it doesn't have access to the user's private, real-time bank information
#
# **Quesstion** To solve this problem, which component would an AI Agent need to use to find the user's current account balance?
# > A. More powerful LLM<br>
# > B. More detailed set of instructions in the system prompt<br>
# > C. Tools such as `get_account_balance` API function<br>
# > D. Memory to remember the user's previous transactions<br>
#
# <details><summary>Answer</summary>
# C. To get real-time, private information like a bank account balance, the agent needs to use a Tool. The LLM would reason that it needs this information and then use the orchestration layer to call the appropriate tool
# </details>
#
# ### Why build with Agents?
#
# While powerful, standalone LLMs often fall short when faced with complex, broader tasks requiring multiple steps, planning, and sophisticated reasoning. These tasks often demand accessing external, real-time information or tools outside the LLMs training data.
#
# Agents bridge this gap by integrating LLM reasoning with tools and planning capabilities. They enable the execution of workflows and all actions in the "real world", whether digital or physical via APIs, to compelte tasks.

# %% [markdown]
# ##
